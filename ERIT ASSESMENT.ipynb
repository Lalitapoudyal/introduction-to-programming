# %%
class ChessGame:
    def _init_(self,board):
        self.board = self.create_board()
        self.current_player = "White"
        self.moves_history = []

    def create_board(self):
        board = {}
        # Create an 8x8 chess board with initial piece positions
        for row in range(8):
            for col in range(8):
                position = chr(col + 97) + str(8 - row)
                board[position] = None
        return board

    def print_board(self):
        # Print the current state of the chess board
        for row in range(8):
            for col in range(8):
                position = chr(col + 97) + str(8 - row)
                print(self.board[position] or ".", end=" ")
            print()
        print()

    def get_move(self):
        # Prompt the current player for a move
        print(f"{self.current_player}'s turn:")
        move = input("Enter your move (e.g., 'e2 e4'): ")
        return move.split()

    def make_move(self, move):
        # Update the board with the move
        start_pos, end_pos = move

        piece = self.board[start_pos]
        self.board[start_pos] = None
        self.board[end_pos] = piece

        self.moves_history.append(move)

    def parse_position(self, position):
        # Convert algebraic notation to board coordinates
        col = ord(position[0]) - 97
        row = 8 - int(position[1])
        return row, col

    def is_valid_move(self, move):
        # Implement your logic for move validation
        return True

    def is_checkmate(self):
        # Implement your logic for checkmate detection
        return False

    def play(self):
        while True:
            self.print_board()
            move = self.get_move()

            if self.is_valid_move(move):
                self.make_move(move)
                if self.is_checkmate():
                    print("Checkmate!")
                    break
                self.current_player = "Black" if self.current_player == "White" else "White"
            else:
                print("Invalid move. Try again.")

        print("Game Over.")

# %%
game = ChessGame()
game.play()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 game = ChessGame()
# ----> 2 game.play()
#
# Cell In[4], line 57, in ChessGame.play(self)
#      55 def play(self):
#      56     while True:
# ---> 57         self.print_board()
#      58         move = self.get_move()
#      60         if self.is_valid_move(move):
#
# Cell In[4], line 21, in ChessGame.print_board(self)
#      19     for col in range(8):
#      20         position = chr(col + 97) + str(8 - row)
# ---> 21         print(self.board[position] or ".", end=" ")
#      22     print()
#      23 print()
#
# AttributeError: 'ChessGame' object has no attribute 'board'

# %%
from chatterbot import ChatBot
from chatterbot.trainers import ChatterBotCorpusTrainer

# Create a ChatBot instance
chatbot = ChatBot('MyChatBot')

# Create a new trainer for the chatbot
trainer = ChatterBotCorpusTrainer(chatbot)

# Train the chatbot using the English corpus
trainer.train('chatterbot.corpus.english')

# Start the conversation loop
while True:
    # Get user input
    user_input = input("You: ")

    # Exit the loop if the user enters 'exit'
    if user_input.lower() == 'exit':
        break

    # Get the chatbot's response
    bot_response = chatbot.get_response(user_input)

    print("ChatBot:", bot_response)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from chatterbot import ChatBot
#       2 from chatterbot.trainers import ChatterBotCorpusTrainer
#       4 # Create a ChatBot instance
#
# ModuleNotFoundError: No module named 'chatterbot'

# %%
# Chess game

# Initialize the chessboard
board = [['R', 'N', 'B', 'Q', 'K', 'B', 'N', 'R'],
         ['P', 'P', 'P', 'P', 'P', 'P', 'P', 'P'],
         ['R', 'N', 'B', 'Q', 'K', 'B', 'N', 'R'],
         ['R', 'N', 'B', 'Q', 'K', 'B', 'N', 'R'],
         ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p'],
         ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p'],
         ['r', 'n', 'b', 'q', 'k', 'b', 'n', 'r']]

# Function to print the chessboard
def print_board(board):
    for row in board:
        print(' '.join(row))
    print()

# Function to check if the move is valid
def is_valid_move(board, start, end):
    # Check if start and end positions are valid
    if not is_valid_position(start) or not is_valid_position(end):
        return False
    
    # Get the piece at the start position
    piece = board[start[0]][start[1]]
    
    # Check if the start position contains a piece
    if piece == ' ':
        return False
    
    # Check if the move is valid for the piece
    if piece.lower() == 'p':  # Pawn
        return is_valid_move_pawn(board, start, end)
    elif piece.lower() == 'r':  # Rook
        return is_valid_move_rook(start, end)
    elif piece.lower() == 'n':  # Knight
        return is_valid_move_knight(start, end)
    elif piece.lower() == 'b':  # Bishop
        return is_valid_move_bishop(start, end)
    elif piece.lower() == 'q':  # Queen
        return is_valid_move_queen(start, end)
    elif piece.lower() == 'k':  # King
        return is_valid_move_king(start, end)
    
    return False

# Function to check if the position is valid
def is_valid_position(position):
    row, col = position
    return 0 <= row < 8 and 0 <= col < 8

# Function to check if the move is valid for a pawn
def is_valid_move_pawn(board, start, end):
    start_row, start_col = start
    end_row, end_col = end
    
    piece = board[start_row][start_col]
    
    if piece == 'P':  # White pawn
        if start_col == end_col:
            if start_row == 1 and end_row == 3 and board[2][start_col] == ' ':
                return True
            elif end_row - start_row == 1 and board[end_row][end_col] == ' ':
                return True
        elif abs(end_col - start_col) == 1 and end_row - start_row == 1 and board[end_row][end_col].islower():
            return True
    elif piece == 'p':  # Black pawn
# Out:
#   Cell In[2], line 67
#     elif piece == 'p':  # Black pawn
#                                     ^
# SyntaxError: incomplete input
